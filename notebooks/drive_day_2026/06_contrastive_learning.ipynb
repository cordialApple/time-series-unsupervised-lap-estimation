# %% [markdown]
# # 06 — Contrastive learning
#
# **Dataset:** `drive_day_2026`
#
# **Question:** Do conservative signal augmentations improve recurrence retrieval?
#
# ## Method
#
# Train compact encoder with mild amplitude, noise, and masking views on training recordings.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "lap_estimation").exists():
    ROOT = ROOT.parent
if not (ROOT / "lap_estimation").exists():
    raise FileNotFoundError("Repository root not found")
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from lap_estimation.plotting_learned import render_contrastive_diagnostics
from lap_estimation.artifacts import load_experiment_metrics
from lap_estimation.config import RANDOM_SEED
from lap_estimation.data import prepare_recording_manifest
from lap_estimation.datasets import resolve_dataset
from lap_estimation.runners import run_experiment

DATASET_KEY = "drive_day_2026"
dataset = resolve_dataset(DATASET_KEY, ROOT)
ARTIFACT_ROOT = dataset.artifact_root
np.random.seed(RANDOM_SEED)
sns.set_theme(style="ticks", palette="colorblind", context="notebook")
manifest = prepare_recording_manifest(dataset)
manifest[["recording_id", "duration_s", "motion_status", "control_candidate", "clock_provenance", "split"]]
# Out:
#                                          recording_id  duration_s  \
# 0   07173121b1534f1eadb8b127005d4eff70872388074c2b...        21.9
# 1   1a8433bf1168531d6f7c2deb5c37b27de5ddf1d9f65316...        21.9
# 2   1cca7c275163fc193899535ebb0c13f26676e8568d3c8a...        37.9
# 3   200a690cbeb5a4d9f415d6a933e60aa13a0cf5ee5c03c7...        57.8
# 4   25aa01e1dcbaea32c062e01b0f782c938c34163fc58af1...        73.7
# 5   2f775054c4e7bb342cf49e0ee66406e82353c274c103fc...        25.9
# 6   382db1f8ede73f956341d7b461790125339762ec9d7cc9...        57.8
# 7   4c8d0190b666e26315ce16c862ca2e968d576e14537487...        21.9
# 8   554af5ad576c1c1d069356649e3bd1e2699a5801f6a0fa...        17.9
# 9   564a12f3d813c10242613a907d2b4981e7296739ba9a56...        57.8
# 10  5e9e04831922d971561f6ffb53b2c77744d905cca01dcc...        41.8
# 11  629d7d57091b71c5c0c2c6f42218702e454b4ae60e2063...        85.7
# 12  667a6e15a4394db30d7cce7a4db319041453bfa306b566...       229.1
# 13  67460352e955edbaf8a0e73406f2aa4726aa14abea0a93...        37.9
# 14  6939b3836a088e9113eb3bffcf362bed963a71bbd9012e...        65.7
# 15  6faa006353747cbeb4e6d2e90954728110cb94fabfcd41...        89.6
# 16  953f71ef131b4c5ce7211560abcbafbfe0079e72cf2190...        89.6
# 17  c5c639ca1fa3038e565a432a960cb53f6ce533ad9612d2...        33.8
# 18  e57d3de89d6f2a3165aa05beee7b611f60923e09025433...        57.8
# 19  f26c5b91a912f9e98e0205e2518d5b3de0314b04b69c3b...        21.9
# 20  f8a2dfe19bc591bed40778fcb493d9a34a3261518b2f4b...        41.8
#
#            motion_status  control_candidate      clock_provenance       split
# 0       moving_candidate              False  recorded_time_column       train
# 1       moving_candidate              False  recorded_time_column       train
# 2       moving_candidate              False  recorded_time_column       train
# 3       moving_candidate              False  recorded_time_column       train
# 4       moving_candidate              False  recorded_time_column       train
# 5       moving_candidate              False  recorded_time_column       train
# 6   stationary_candidate               True  recorded_time_column       train
# 7       moving_candidate              False  recorded_time_column       train
# 8   stationary_candidate               True  recorded_time_column       train
# 9   stationary_candidate               True  recorded_time_column       train
# 10      moving_candidate              False  recorded_time_column       train
# 11      moving_candidate              False  recorded_time_column       train
# 12      moving_candidate              False  recorded_time_column       train
# 13      moving_candidate              False  recorded_time_column       train
# 14      moving_candidate              False  recorded_time_column  validation
# 15      moving_candidate              False  recorded_time_column  validation
# 16  stationary_candidate               True  recorded_time_column  validation
# 17  stationary_candidate               True  recorded_time_column        test
# 18      moving_candidate              False  recorded_time_column        test
# 19      moving_candidate              False  recorded_time_column        test
# 20      moving_candidate              False  recorded_time_column        test

# %%
EXPERIMENT_OPTIONS = {'epochs': 20}
EXPERIMENT_OPTIONS
# Out:
# {'epochs': 20}

# %%
METHOD = "06_contrastive_learning"
result = run_experiment(METHOD, ROOT, dataset_key=DATASET_KEY, **EXPERIMENT_OPTIONS)
run_manifest = json.loads((result.output_dir / "manifest.json").read_text(encoding="utf-8"))
display(result.metrics)
display(result.predictions.describe(include="all").T)
display(result.predictions.groupby("recording_id")["score"].agg(["count", "mean", "median", "std", "min", "max"]).sort_values("median", ascending=False))
diagnostic_figures = render_contrastive_diagnostics(result.predictions, run_manifest, result.output_dir)
for figure in diagnostic_figures.values():
    display(figure)
    plt.close(figure)
# Out:
#                      task       split                           metric  \
# 0  augmentation_retrieval       train      mean_view_cosine_similarity
# 1  augmentation_retrieval  validation      mean_view_cosine_similarity
# 2  augmentation_retrieval        test      mean_view_cosine_similarity
# 3  augmentation_retrieval         all      mean_view_cosine_similarity
# 4     embedding_retrieval       train  mean_neighbor_cosine_similarity
# 5     embedding_retrieval  validation  mean_neighbor_cosine_similarity
# 6     embedding_retrieval        test  mean_neighbor_cosine_similarity
# 7     embedding_retrieval         all  mean_neighbor_cosine_similarity
#
#       value  sample_count           reference_source
# 0  0.987574           333  same_window_augmentations
# 1  0.990201           108  same_window_augmentations
# 2  0.989195            59  same_window_augmentations
# 3  0.988333           500  same_window_augmentations
# 4  0.982732           333                       none
# 5  0.991515           108                       none
# 6  0.986595            59                       none
# 7  0.985085           500                       none
#                        count unique  \
# recording_id             500     21
# segment_id               500    500
# start_s                500.0    NaN
# end_s                  500.0    NaN
# prediction_kind          500      1
# score                  500.0    NaN
# label_status             500      1
# neighbor_recording_id    500     21
# neighbor_start_s       500.0    NaN
# temporal_separation_s  500.0    NaN
#
#                                                                      top freq  \
# recording_id           667a6e15a4394db30d7cce7a4db319041453bfa306b566...  110
# segment_id                                                      window_0    1
# start_s                                                              NaN  NaN
# end_s                                                                NaN  NaN
# prediction_kind                           contrastive_embedding_neighbor  500
# score                                                                NaN  NaN
# label_status                                      provisional_unverified  500
# neighbor_recording_id  667a6e15a4394db30d7cce7a4db319041453bfa306b566...   95
# neighbor_start_s                                                     NaN  NaN
# temporal_separation_s                                                NaN  NaN
#
#                            mean        std       min       25%       50%  \
# recording_id                NaN        NaN       NaN       NaN       NaN
# segment_id                  NaN        NaN       NaN       NaN       NaN
# start_s                  43.528  49.015163       0.0      11.5      27.0
# end_s                    53.528  49.015163      10.0      21.5      37.0
# prediction_kind             NaN        NaN       NaN       NaN       NaN
# score                  0.985085   0.023786  0.803441  0.982175  0.993734
# label_status                NaN        NaN       NaN       NaN       NaN
# neighbor_recording_id       NaN        NaN       NaN       NaN       NaN
# neighbor_start_s          42.06  48.457783       0.0      10.0      26.0
# temporal_separation_s    48.452  49.665935       0.0      17.5      30.0
#
#                             75%    max
# recording_id                NaN    NaN
# segment_id                  NaN    NaN
# 07173121b1534f1eadb8b127005d4eff70872388074c2bb...  1.931167e-02  0.947420
# 1cca7c275163fc193899535ebb0c13f26676e8568d3c8ad...  1.902777e-02  0.948241
# e57d3de89d6f2a3165aa05beee7b611f60923e090254337...  1.793094e-02  0.919342
# f8a2dfe19bc591bed40778fcb493d9a34a3261518b2f4b4...  1.591311e-02  0.947555
# 5e9e04831922d971561f6ffb53b2c77744d905cca01dcc2...  2.069147e-02  0.919638
# f26c5b91a912f9e98e0205e2518d5b3de0314b04b69c3bc...  1.856192e-02  0.940737
# 667a6e15a4394db30d7cce7a4db319041453bfa306b566a...  3.270951e-02  0.803441
# 4c8d0190b666e26315ce16c862ca2e968d576e145374871...  3.174603e-02  0.900331
# 1a8433bf1168531d6f7c2deb5c37b27de5ddf1d9f653164...  2.332061e-02  0.902902
# 2f775054c4e7bb342cf49e0ee66406e82353c274c103fc7...  1.901635e-02  0.931034
#
#                                                          max
# recording_id
# 554af5ad576c1c1d069356649e3bd1e2699a5801f6a0fa7...  1.000000
# 953f71ef131b4c5ce7211560abcbafbfe0079e72cf2190c...  1.000000
# 382db1f8ede73f956341d7b461790125339762ec9d7cc96...  1.000000
# 564a12f3d813c10242613a907d2b4981e7296739ba9a560...  1.000000
# c5c639ca1fa3038e565a432a960cb53f6ce533ad9612d27...  0.999984
# 25aa01e1dcbaea32c062e01b0f782c938c34163fc58af14...  1.000000
# 200a690cbeb5a4d9f415d6a933e60aa13a0cf5ee5c03c71...  1.000000
# 6faa006353747cbeb4e6d2e90954728110cb94fabfcd41e...  0.999799
# 6939b3836a088e9113eb3bffcf362bed963a71bbd9012ec...  1.000000
# 67460352e955edbaf8a0e73406f2aa4726aa14abea0a93a...  0.999634
# 629d7d57091b71c5c0c2c6f42218702e454b4ae60e20636...  1.000000
# 07173121b1534f1eadb8b127005d4eff70872388074c2bb...  0.996953
# 1cca7c275163fc193899535ebb0c13f26676e8568d3c8ad...  0.999824
# e57d3de89d6f2a3165aa05beee7b611f60923e090254337...  1.000000
# f8a2dfe19bc591bed40778fcb493d9a34a3261518b2f4b4...  1.000000
# 5e9e04831922d971561f6ffb53b2c77744d905cca01dcc2...  0.998224
# f26c5b91a912f9e98e0205e2518d5b3de0314b04b69c3bc...  0.992469
# 667a6e15a4394db30d7cce7a4db319041453bfa306b566a...  0.999998
# 4c8d0190b666e26315ce16c862ca2e968d576e145374871...  0.996195
# 1a8433bf1168531d6f7c2deb5c37b27de5ddf1d9f653164...  0.976870
# 2f775054c4e7bb342cf49e0ee66406e82353c274c103fc7...  0.982592

# %%
pd.Series(
    {
        "status": run_manifest["status"],
        "runtime_s": run_manifest["runtime_s"],
        "clock_provenance": run_manifest["data_provenance"]["clock_provenance"],
        "sample_rate_hz": run_manifest["data_provenance"]["native_sample_rate_hz"],
        "channels": run_manifest["data_provenance"]["selected_channels"],
        "label_provenance": run_manifest["label_provenance"],
    },
    name="value",
).to_frame()
# Out:
#                                                               value
# status                                                     complete
# runtime_s                                                     8.493
# clock_provenance                               recorded_time_column
# sample_rate_hz                                                 10.0
# channels          [Motor RPM [Rpm], MC Duty Cycle [%], AC Curren...
# label_provenance               same_window_augmentations_unverified

# %% [markdown]
# ## Reading
#
# View consistency measures augmentation invariance, not lap detection.
#
# No lap precision, recall, count error, or duration error can be reported without independently reviewed boundaries.
