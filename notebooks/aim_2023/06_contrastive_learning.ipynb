# %% [markdown]
# # 06 — Contrastive learning
#
# **Dataset:** `aim_2023`
#
# **Question:** Do conservative signal augmentations improve recurrence retrieval?
#
# ## Method
#
# Train compact encoder with mild amplitude, noise, and masking views on training recordings.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "lap_estimation").exists():
    ROOT = ROOT.parent
if not (ROOT / "lap_estimation").exists():
    raise FileNotFoundError("Repository root not found")
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from lap_estimation.plotting_learned import render_contrastive_diagnostics
from lap_estimation.artifacts import load_experiment_metrics
from lap_estimation.config import RANDOM_SEED
from lap_estimation.data import prepare_recording_manifest
from lap_estimation.datasets import resolve_dataset
from lap_estimation.runners import run_experiment

DATASET_KEY = "aim_2023"
dataset = resolve_dataset(DATASET_KEY, ROOT)
ARTIFACT_ROOT = dataset.artifact_root
np.random.seed(RANDOM_SEED)
sns.set_theme(style="ticks", palette="colorblind", context="notebook")
manifest = prepare_recording_manifest(dataset)
manifest[["recording_id", "duration_s", "motion_status", "control_candidate", "clock_provenance", "split"]]
# Out:
#                                          recording_id  duration_s  \
# 0   18385fe48224fbfa0cd6d17705d9305f857d70ef07b47b...      228.95
# 1   27937681c8199780c6cbce603f217d5a4457c351e84fa3...      217.95
# 2   4975a35d789765b9299480af66d6a5af5166fef074cef8...      210.95
# 3   5790cd1534b1de5ac4693367fe5d8ca6951cd36a7abcd3...       25.95
# 4   5c12d7b5eff374be805bae6c5e2906f6c02b6bc3ad6ba7...       89.95
# 5   5c8af6b8a89a449144e0ddf74414040b433d630e1fd3d3...       33.95
# 6   6732a35a8f6343dcf041f1a3ad40d6760331513a2556c4...       21.95
# 7   7208a43e77536a72e401c00f01a793130fb6688d28fb80...        9.95
# 8   73093667f33a7f710fc20059989a002071359119e1e9c0...       10.95
# 9   8f799d59c9b5348ece1e5671692ea783d6d5e450ccebe3...      107.95
# 10  9116cbf4be063f5be851f65778ddfb91d60bdd5aa52e72...      456.95
# 11  973ef84ffaa4e83d002ed655331eb305b340c0f3f25b57...       12.95
# 12  b185f43818b8ff3aba325752922bbbf37fd094f1e28288...      123.95
# 13  b439fc5983a3a0db22239d5dcf8cbebf9104a8b71a93c2...       10.95
# 14  bace0e92b25324e8afbd0e5f6698b01a921780a2385e02...      241.95
# 15  c3c503093a73b359d513d025d9185c7ada423099650828...       20.95
# 16  db4d46d3c8abd3b8d2327e52a99599c63e7bd8ed5f1b12...       19.95
# 17  dc8bf44eb4cc0becf1c5ebe252a515c98193744c203149...      175.95
#
#              motion_status  control_candidate                clock_provenance  \
# 0        dynamic_candidate              False  inferred_uniform_from_metadata
# 1        dynamic_candidate              False  inferred_uniform_from_metadata
# 2        dynamic_candidate              False  inferred_uniform_from_metadata
# 3   low_dynamics_candidate               True  inferred_uniform_from_metadata
# 4        dynamic_candidate              False  inferred_uniform_from_metadata
# 5   low_dynamics_candidate               True  inferred_uniform_from_metadata
# 6        dynamic_candidate              False  inferred_uniform_from_metadata
# 7   low_dynamics_candidate               True  inferred_uniform_from_metadata
# 8   low_dynamics_candidate               True  inferred_uniform_from_metadata
# 9        dynamic_candidate              False  inferred_uniform_from_metadata
# 10       dynamic_candidate              False  inferred_uniform_from_metadata
# 11       dynamic_candidate              False  inferred_uniform_from_metadata
# 12       dynamic_candidate              False  inferred_uniform_from_metadata
# 13  low_dynamics_candidate               True  inferred_uniform_from_metadata
# 14       dynamic_candidate              False  inferred_uniform_from_metadata
# 15       dynamic_candidate              False  inferred_uniform_from_metadata
# 16  low_dynamics_candidate               True  inferred_uniform_from_metadata
# 17  low_dynamics_candidate               True  inferred_uniform_from_metadata
#
#          split
# 0        train
# 1        train
# 2        train
# 3        train
# 4        train
# 5        train
# 6        train
# 7        train
# 8        train
# 9        train
# 10       train
# 11  validation
# 12  validation
# 13  validation
# 14        test
# 15        test
# 16        test
# 17        test

# %%
EXPERIMENT_OPTIONS = {'epochs': 20}
EXPERIMENT_OPTIONS
# Out:
# {'epochs': 20}

# %%
METHOD = "06_contrastive_learning"
result = run_experiment(METHOD, ROOT, dataset_key=DATASET_KEY, **EXPERIMENT_OPTIONS)
run_manifest = json.loads((result.output_dir / "manifest.json").read_text(encoding="utf-8"))
display(result.metrics)
display(result.predictions.describe(include="all").T)
display(result.predictions.groupby("recording_id")["score"].agg(["count", "mean", "median", "std", "min", "max"]).sort_values("median", ascending=False))
diagnostic_figures = render_contrastive_diagnostics(result.predictions, run_manifest, result.output_dir)
for figure in diagnostic_figures.values():
    display(figure)
    plt.close(figure)
# Out:
#                      task       split                           metric  \
# 0  augmentation_retrieval       train      mean_view_cosine_similarity
# 1  augmentation_retrieval  validation      mean_view_cosine_similarity
# 2  augmentation_retrieval        test      mean_view_cosine_similarity
# 3  augmentation_retrieval         all      mean_view_cosine_similarity
# 4     embedding_retrieval       train  mean_neighbor_cosine_similarity
# 5     embedding_retrieval  validation  mean_neighbor_cosine_similarity
# 6     embedding_retrieval        test  mean_neighbor_cosine_similarity
# 7     embedding_retrieval         all  mean_neighbor_cosine_similarity
#
#       value  sample_count           reference_source
# 0  0.986389           662  same_window_augmentations
# 1  0.981839            61  same_window_augmentations
# 2  0.989772           213  same_window_augmentations
# 3  0.986863           936  same_window_augmentations
# 4  0.967497           662                       none
# 5  0.969139            61                       none
# 6  0.981220           213                       none
# 7  0.970727           936                       none
#                        count unique  \
# recording_id             936     18
# segment_id               936    936
# start_s                936.0    NaN
# end_s                  936.0    NaN
# prediction_kind          936      1
# score                  936.0    NaN
# label_status             936      1
# neighbor_recording_id    936     18
# neighbor_start_s       936.0    NaN
# temporal_separation_s  936.0    NaN
#
#                                                                      top freq  \
# recording_id           9116cbf4be063f5be851f65778ddfb91d60bdd5aa52e72...  224
# segment_id                                                      window_0    1
# start_s                                                              NaN  NaN
# end_s                                                                NaN  NaN
# prediction_kind                           contrastive_embedding_neighbor  936
# score                                                                NaN  NaN
# label_status                                      provisional_unverified  936
# neighbor_recording_id  9116cbf4be063f5be851f65778ddfb91d60bdd5aa52e72...  212
# neighbor_start_s                                                     NaN  NaN
# temporal_separation_s                                                NaN  NaN
#
#                              mean         std       min       25%       50%  \
# recording_id                  NaN         NaN       NaN       NaN       NaN
# segment_id                    NaN         NaN       NaN       NaN       NaN
# start_s                118.839744  101.772946       0.0      40.0      94.0
# end_s                  128.839744  101.772946      10.0      50.0     104.0
# prediction_kind               NaN         NaN       NaN       NaN       NaN
# score                    0.970727    0.031324  0.755942  0.960149  0.980198
# label_status                  NaN         NaN       NaN       NaN       NaN
# neighbor_recording_id         NaN         NaN       NaN       NaN       NaN
# neighbor_start_s       114.173077   99.942358       0.0      41.5      87.0
# temporal_separation_s   90.568376   94.718461       0.0      28.0      58.0
#
#                             75%      max
# recording_id                NaN      NaN
# segment_id                  NaN      NaN
# start_s                   168.0    446.0
# end_s                     178.0    456.0
# prediction_kind             NaN      NaN
# score                  0.991153  0.99997
# label_status                NaN      NaN
# neighbor_recording_id       NaN      NaN
# neighbor_start_s          160.0    444.0
# temporal_separation_s     114.0    446.0
#                                                     count      mean    median  \
# recording_id
# dc8bf44eb4cc0becf1c5ebe252a515c98193744c2031498...     84  0.987447  0.996828
# bace0e92b25324e8afbd0e5f6698b01a921780a2385e024...    117  0.979539  0.987231
# 18385fe48224fbfa0cd6d17705d9305f857d70ef07b47b5...    110  0.967955  0.982802
# 4975a35d789765b9299480af66d6a5af5166fef074cef80...    101  0.964963  0.980412
# 5c8af6b8a89a449144e0ddf74414040b433d630e1fd3d3d...     13  0.976532  0.980090
# 9116cbf4be063f5be851f65778ddfb91d60bdd5aa52e721...    224  0.970231  0.979522
# 27937681c8199780c6cbce603f217d5a4457c351e84fa3c...    105  0.964088  0.978669
# b439fc5983a3a0db22239d5dcf8cbebf9104a8b71a93c2a...      1  0.977824  0.977824
# b185f43818b8ff3aba325752922bbbf37fd094f1e282887...     58  0.969023  0.975712
# 73093667f33a7f710fc20059989a002071359119e1e9c0a...      1  0.975678  0.975678
# 8f799d59c9b5348ece1e5671692ea783d6d5e450ccebe31...     50  0.970524  0.974357
# 5c12d7b5eff374be805bae6c5e2906f6c02b6bc3ad6ba70...     41  0.968272  0.970877
# 7208a43e77536a72e401c00f01a793130fb6688d28fb808...      1  0.970506  0.970506
# db4d46d3c8abd3b8d2327e52a99599c63e7bd8ed5f1b122...      6  0.969334  0.968524
# 973ef84ffaa4e83d002ed655331eb305b340c0f3f25b577...      2  0.968186  0.968186
# 5790cd1534b1de5ac4693367fe5d8ca6951cd36a7abcd3c...      9  0.945703  0.946197
# c3c503093a73b359d513d025d9185c7ada423099650828c...      6  0.938704  0.940305
# 6732a35a8f6343dcf041f1a3ad40d6760331513a2556c4f...      7  0.944033  0.938225
#
#                                                          std       min  \
# recording_id
# dc8bf44eb4cc0becf1c5ebe252a515c98193744c2031498...  0.022896  0.891409
# bace0e92b25324e8afbd0e5f6698b01a921780a2385e024...  0.024348  0.873545
# 18385fe48224fbfa0cd6d17705d9305f857d70ef07b47b5...  0.032956  0.841113
# 4975a35d789765b9299480af66d6a5af5166fef074cef80...  0.042864  0.755942
# 5c8af6b8a89a449144e0ddf74414040b433d630e1fd3d3d...  0.013278  0.950256
# 9116cbf4be063f5be851f65778ddfb91d60bdd5aa52e721...  0.028755  0.823064
# 27937681c8199780c6cbce603f217d5a4457c351e84fa3c...  0.039900  0.770377
# b439fc5983a3a0db22239d5dcf8cbebf9104a8b71a93c2a...       NaN  0.977824
# b185f43818b8ff3aba325752922bbbf37fd094f1e282887...  0.029564  0.810204
# 73093667f33a7f710fc20059989a002071359119e1e9c0a...       NaN  0.975678
# 8f799d59c9b5348ece1e5671692ea783d6d5e450ccebe31...  0.018186  0.922065
# 5c12d7b5eff374be805bae6c5e2906f6c02b6bc3ad6ba70...  0.018591  0.877779
# 7208a43e77536a72e401c00f01a793130fb6688d28fb808...       NaN  0.970506
# db4d46d3c8abd3b8d2327e52a99599c63e7bd8ed5f1b122...  0.008229  0.959894
# 973ef84ffaa4e83d002ed655331eb305b340c0f3f25b577...  0.006110  0.963865
# 5790cd1534b1de5ac4693367fe5d8ca6951cd36a7abcd3c...  0.027095  0.904741
# c3c503093a73b359d513d025d9185c7ada423099650828c...  0.028488  0.908308
# 6732a35a8f6343dcf041f1a3ad40d6760331513a2556c4f...  0.016395  0.925544
#
#                                                          max
# recording_id
# dc8bf44eb4cc0becf1c5ebe252a515c98193744c2031498...  0.999652
# bace0e92b25324e8afbd0e5f6698b01a921780a2385e024...  0.999765
# 18385fe48224fbfa0cd6d17705d9305f857d70ef07b47b5...  0.999089
# 4975a35d789765b9299480af66d6a5af5166fef074cef80...  0.998090
# 5c8af6b8a89a449144e0ddf74414040b433d630e1fd3d3d...  0.996182
# 9116cbf4be063f5be851f65778ddfb91d60bdd5aa52e721...  0.999970
# 27937681c8199780c6cbce603f217d5a4457c351e84fa3c...  0.997009
# b439fc5983a3a0db22239d5dcf8cbebf9104a8b71a93c2a...  0.977824
# b185f43818b8ff3aba325752922bbbf37fd094f1e282887...  0.998866
# 73093667f33a7f710fc20059989a002071359119e1e9c0a...  0.975678
# 8f799d59c9b5348ece1e5671692ea783d6d5e450ccebe31...  0.995088
# 5c12d7b5eff374be805bae6c5e2906f6c02b6bc3ad6ba70...  0.997224
# 7208a43e77536a72e401c00f01a793130fb6688d28fb808...  0.970506
# db4d46d3c8abd3b8d2327e52a99599c63e7bd8ed5f1b122...  0.979701
# 973ef84ffaa4e83d002ed655331eb305b340c0f3f25b577...  0.972506
# 5790cd1534b1de5ac4693367fe5d8ca6951cd36a7abcd3c...  0.978067
# c3c503093a73b359d513d025d9185c7ada423099650828c...  0.971104
# 6732a35a8f6343dcf041f1a3ad40d6760331513a2556c4f...  0.966543

# %%
pd.Series(
    {
        "status": run_manifest["status"],
        "runtime_s": run_manifest["runtime_s"],
        "clock_provenance": run_manifest["data_provenance"]["clock_provenance"],
        "sample_rate_hz": run_manifest["data_provenance"]["native_sample_rate_hz"],
        "channels": run_manifest["data_provenance"]["selected_channels"],
        "label_provenance": run_manifest["label_provenance"],
    },
    name="value",
).to_frame()
# Out:
#                                                               value
# status                                                     complete
# runtime_s                                                     9.557
# clock_provenance                     inferred_uniform_from_metadata
# sample_rate_hz                                                 20.0
# channels          [InlineAcc, LateralAcc, RollRate, PitchRate, Y...
# label_provenance               same_window_augmentations_unverified

# %% [markdown]
# ## Reading
#
# View consistency measures augmentation invariance, not lap detection.
#
# No lap precision, recall, count error, or duration error can be reported without independently reviewed boundaries.
