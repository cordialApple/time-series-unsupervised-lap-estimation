# %% [markdown]
# # 07 — Sequence models
#
# **Dataset:** `aim_2023`
#
# **Question:** Does compact GRU prediction beat persistence on held-out recordings?
#
# ## Method
#
# Train next-sample GRU on training windows and compare against unchanged-value persistence.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "lap_estimation").exists():
    ROOT = ROOT.parent
if not (ROOT / "lap_estimation").exists():
    raise FileNotFoundError("Repository root not found")
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from lap_estimation.plotting_learned import render_sequence_diagnostics
from lap_estimation.artifacts import load_experiment_metrics
from lap_estimation.config import RANDOM_SEED
from lap_estimation.data import prepare_recording_manifest
from lap_estimation.datasets import resolve_dataset
from lap_estimation.runners import run_experiment

DATASET_KEY = "aim_2023"
dataset = resolve_dataset(DATASET_KEY, ROOT)
ARTIFACT_ROOT = dataset.artifact_root
np.random.seed(RANDOM_SEED)
sns.set_theme(style="ticks", palette="colorblind", context="notebook")
manifest = prepare_recording_manifest(dataset)
manifest[["recording_id", "duration_s", "motion_status", "control_candidate", "clock_provenance", "split"]]
# Out:
#                                          recording_id  duration_s  \
# 0   18385fe48224fbfa0cd6d17705d9305f857d70ef07b47b...      228.95
# 1   27937681c8199780c6cbce603f217d5a4457c351e84fa3...      217.95
# 2   4975a35d789765b9299480af66d6a5af5166fef074cef8...      210.95
# 3   5790cd1534b1de5ac4693367fe5d8ca6951cd36a7abcd3...       25.95
# 4   5c12d7b5eff374be805bae6c5e2906f6c02b6bc3ad6ba7...       89.95
# 5   5c8af6b8a89a449144e0ddf74414040b433d630e1fd3d3...       33.95
# 6   6732a35a8f6343dcf041f1a3ad40d6760331513a2556c4...       21.95
# 7   7208a43e77536a72e401c00f01a793130fb6688d28fb80...        9.95
# 8   73093667f33a7f710fc20059989a002071359119e1e9c0...       10.95
# 9   8f799d59c9b5348ece1e5671692ea783d6d5e450ccebe3...      107.95
# 10  9116cbf4be063f5be851f65778ddfb91d60bdd5aa52e72...      456.95
# 11  973ef84ffaa4e83d002ed655331eb305b340c0f3f25b57...       12.95
# 12  b185f43818b8ff3aba325752922bbbf37fd094f1e28288...      123.95
# 13  b439fc5983a3a0db22239d5dcf8cbebf9104a8b71a93c2...       10.95
# 14  bace0e92b25324e8afbd0e5f6698b01a921780a2385e02...      241.95
# 15  c3c503093a73b359d513d025d9185c7ada423099650828...       20.95
# 16  db4d46d3c8abd3b8d2327e52a99599c63e7bd8ed5f1b12...       19.95
# 17  dc8bf44eb4cc0becf1c5ebe252a515c98193744c203149...      175.95
#
#              motion_status  control_candidate                clock_provenance  \
# 0        dynamic_candidate              False  inferred_uniform_from_metadata
# 1        dynamic_candidate              False  inferred_uniform_from_metadata
# 2        dynamic_candidate              False  inferred_uniform_from_metadata
# 3   low_dynamics_candidate               True  inferred_uniform_from_metadata
# 4        dynamic_candidate              False  inferred_uniform_from_metadata
# 5   low_dynamics_candidate               True  inferred_uniform_from_metadata
# 6        dynamic_candidate              False  inferred_uniform_from_metadata
# 7   low_dynamics_candidate               True  inferred_uniform_from_metadata
# 8   low_dynamics_candidate               True  inferred_uniform_from_metadata
# 9        dynamic_candidate              False  inferred_uniform_from_metadata
# 10       dynamic_candidate              False  inferred_uniform_from_metadata
# 11       dynamic_candidate              False  inferred_uniform_from_metadata
# 12       dynamic_candidate              False  inferred_uniform_from_metadata
# 13  low_dynamics_candidate               True  inferred_uniform_from_metadata
# 14       dynamic_candidate              False  inferred_uniform_from_metadata
# 15       dynamic_candidate              False  inferred_uniform_from_metadata
# 16  low_dynamics_candidate               True  inferred_uniform_from_metadata
# 17  low_dynamics_candidate               True  inferred_uniform_from_metadata
#
#          split
# 0        train
# 1        train
# 2        train
# 3        train
# 4        train
# 5        train
# 6        train
# 7        train
# 8        train
# 9        train
# 10       train
# 11  validation
# 12  validation
# 13  validation
# 14        test
# 15        test
# 16        test
# 17        test

# %%
EXPERIMENT_OPTIONS = {'epochs': 20}
EXPERIMENT_OPTIONS
# Out:
# {'epochs': 20}

# %%
METHOD = "07_sequence_models"
result = run_experiment(METHOD, ROOT, dataset_key=DATASET_KEY, **EXPERIMENT_OPTIONS)
run_manifest = json.loads((result.output_dir / "manifest.json").read_text(encoding="utf-8"))
display(result.metrics)
display(result.predictions.describe(include="all").T)
display(result.predictions.groupby("recording_id")["score"].agg(["count", "mean", "median", "std", "min", "max"]).sort_values("median", ascending=False))
diagnostic_figures = render_sequence_diagnostics(result.predictions, run_manifest, result.output_dir)
for figure in diagnostic_figures.values():
    display(figure)
    plt.close(figure)
# Out:
#                      task       split           metric      value  \
# 0  next_sample_prediction       train          gru_mse  33.914346
# 1  next_sample_prediction  validation          gru_mse  71.156231
# 2  next_sample_prediction        test          gru_mse  15.166861
# 3  next_sample_prediction         all          gru_mse  32.075180
# 4  next_sample_prediction       train  persistence_mse   4.306843
# 5  next_sample_prediction  validation  persistence_mse  10.307184
# 6  next_sample_prediction        test  persistence_mse   1.941405
# 7  next_sample_prediction         all  persistence_mse   4.159602
#
#    sample_count      reference_source
# 0           662                  none
# 1            61                  none
# 2           213                  none
# 3           936                  none
# 4           662  persistence_baseline
# 5            61  persistence_baseline
# 6           213  persistence_baseline
# 7           936  persistence_baseline
#                    count unique  \
# recording_id         936     18
# segment_id           936    936
# start_s            936.0    NaN
# end_s              936.0    NaN
# prediction_kind      936      1
# score              936.0    NaN
# label_status         936      1
# persistence_error  936.0    NaN
#
#                                                                  top freq  \
# recording_id       9116cbf4be063f5be851f65778ddfb91d60bdd5aa52e72...  224
# segment_id                                                  window_0    1
# start_s                                                          NaN  NaN
# end_s                                                            NaN  NaN
# prediction_kind                            sequence_prediction_error  936
# score                                                            NaN  NaN
# label_status                                  provisional_unverified  936
# persistence_error                                                NaN  NaN
#
#                          mean         std       min       25%      50%  \
# recording_id              NaN         NaN       NaN       NaN      NaN
# segment_id                NaN         NaN       NaN       NaN      NaN
# start_s            118.839744  101.772946       0.0      40.0     94.0
# end_s              128.839744  101.772946      10.0      50.0    104.0
# prediction_kind           NaN         NaN       NaN       NaN      NaN
# score                32.07518   48.192819  0.022289  0.101651  0.52028
# label_status              NaN         NaN       NaN       NaN      NaN
# persistence_error    4.159602    6.311298  0.001651  0.063024  0.12791
#
#                          75%        max
# recording_id             NaN        NaN
# segment_id               NaN        NaN
# start_s                168.0      446.0
# end_s                  178.0      456.0
# prediction_kind          NaN        NaN
# score              67.454684  180.28277
# label_status             NaN        NaN
# persistence_error   8.125637  24.499163
#                                                     count       mean  \
# recording_id
# 8f799d59c9b5348ece1e5671692ea783d6d5e450ccebe31...     50  88.120096
# b185f43818b8ff3aba325752922bbbf37fd094f1e282887...     58  74.465518
# 973ef84ffaa4e83d002ed655331eb305b340c0f3f25b577...      2  10.579655
# 9116cbf4be063f5be851f65778ddfb91d60bdd5aa52e721...    224  26.591486
# 4975a35d789765b9299480af66d6a5af5166fef074cef80...    101  37.776920
# 5c8af6b8a89a449144e0ddf74414040b433d630e1fd3d3d...     13   0.588437
# c3c503093a73b359d513d025d9185c7ada423099650828c...      6   0.515279
# 5c12d7b5eff374be805bae6c5e2906f6c02b6bc3ad6ba70...     41   0.500343
# b439fc5983a3a0db22239d5dcf8cbebf9104a8b71a93c2a...      1   0.370755
# 73093667f33a7f710fc20059989a002071359119e1e9c0a...      1   0.261560
# db4d46d3c8abd3b8d2327e52a99599c63e7bd8ed5f1b122...      6   0.176835
# 7208a43e77536a72e401c00f01a793130fb6688d28fb808...      1   0.193362
# 18385fe48224fbfa0cd6d17705d9305f857d70ef07b47b5...    110  30.671954
# 5790cd1534b1de5ac4693367fe5d8ca6951cd36a7abcd3c...      9   0.222097
# 6732a35a8f6343dcf041f1a3ad40d6760331513a2556c4f...      7   0.187835
# bace0e92b25324e8afbd0e5f6698b01a921780a2385e024...    117  27.411042
# 27937681c8199780c6cbce603f217d5a4457c351e84fa3c...    105  46.356984
# dc8bf44eb4cc0becf1c5ebe252a515c98193744c2031498...     84   0.229724
#
#                                                         median        std  \
# recording_id
# 8f799d59c9b5348ece1e5671692ea783d6d5e450ccebe31...  118.633319  60.523362
# b185f43818b8ff3aba325752922bbbf37fd094f1e282887...  103.952492  54.588786
# 973ef84ffaa4e83d002ed655331eb305b340c0f3f25b577...   10.579655   0.269743
# 9116cbf4be063f5be851f65778ddfb91d60bdd5aa52e721...    1.459927  36.153678
# 4975a35d789765b9299480af66d6a5af5166fef074cef80...    0.819733  51.153416
# 5c8af6b8a89a449144e0ddf74414040b433d630e1fd3d3d...    0.790650   0.404679
# c3c503093a73b359d513d025d9185c7ada423099650828c...    0.506914   0.063822
# 5c12d7b5eff374be805bae6c5e2906f6c02b6bc3ad6ba70...    0.460859   0.260909
# b439fc5983a3a0db22239d5dcf8cbebf9104a8b71a93c2a...    0.370755        NaN
# 73093667f33a7f710fc20059989a002071359119e1e9c0a...    0.261560        NaN
# db4d46d3c8abd3b8d2327e52a99599c63e7bd8ed5f1b122...    0.195206   0.077973
# 7208a43e77536a72e401c00f01a793130fb6688d28fb808...    0.193362        NaN
# 18385fe48224fbfa0cd6d17705d9305f857d70ef07b47b5...    0.182957  43.845922
# 5790cd1534b1de5ac4693367fe5d8ca6951cd36a7abcd3c...    0.182527   0.104263
# 6732a35a8f6343dcf041f1a3ad40d6760331513a2556c4f...    0.179776   0.063338
# bace0e92b25324e8afbd0e5f6698b01a921780a2385e024...    0.178704  39.518336
# 27937681c8199780c6cbce603f217d5a4457c351e84fa3c...    0.175882  62.912644
# dc8bf44eb4cc0becf1c5ebe252a515c98193744c2031498...    0.100821   0.626448
#
#                                                           min         max
# recording_id
# 8f799d59c9b5348ece1e5671692ea783d6d5e450ccebe31...   0.526777  158.608851
# b185f43818b8ff3aba325752922bbbf37fd094f1e282887...   0.248209  150.557122
# 973ef84ffaa4e83d002ed655331eb305b340c0f3f25b577...  10.388918   10.770392
# 9116cbf4be063f5be851f65778ddfb91d60bdd5aa52e721...   0.041065  127.234823
# 4975a35d789765b9299480af66d6a5af5166fef074cef80...   0.025737  161.413301
# 5c8af6b8a89a449144e0ddf74414040b433d630e1fd3d3d...   0.126685    1.190719
# c3c503093a73b359d513d025d9185c7ada423099650828c...   0.426322    0.621910
# 5c12d7b5eff374be805bae6c5e2906f6c02b6bc3ad6ba70...   0.083983    1.075652
# b439fc5983a3a0db22239d5dcf8cbebf9104a8b71a93c2a...   0.370755    0.370755
# 73093667f33a7f710fc20059989a002071359119e1e9c0a...   0.261560    0.261560
# db4d46d3c8abd3b8d2327e52a99599c63e7bd8ed5f1b122...   0.072252    0.275258
# 7208a43e77536a72e401c00f01a793130fb6688d28fb808...   0.193362    0.193362
# 18385fe48224fbfa0cd6d17705d9305f857d70ef07b47b5...   0.047513  129.665465
# 5790cd1534b1de5ac4693367fe5d8ca6951cd36a7abcd3c...   0.121084    0.386550
# 6732a35a8f6343dcf041f1a3ad40d6760331513a2556c4f...   0.124431    0.306809
# bace0e92b25324e8afbd0e5f6698b01a921780a2385e024...   0.069282  120.342876
# 27937681c8199780c6cbce603f217d5a4457c351e84fa3c...   0.022289  180.282770
# dc8bf44eb4cc0becf1c5ebe252a515c98193744c2031498...   0.027517    3.721194

# %%
pd.Series(
    {
        "status": run_manifest["status"],
        "runtime_s": run_manifest["runtime_s"],
        "clock_provenance": run_manifest["data_provenance"]["clock_provenance"],
        "sample_rate_hz": run_manifest["data_provenance"]["native_sample_rate_hz"],
        "channels": run_manifest["data_provenance"]["selected_channels"],
        "label_provenance": run_manifest["label_provenance"],
    },
    name="value",
).to_frame()
# Out:
#                                                               value
# status                                                     complete
# runtime_s                                                    26.096
# clock_provenance                     inferred_uniform_from_metadata
# sample_rate_hz                                                 20.0
# channels          [InlineAcc, LateralAcc, RollRate, PitchRate, Y...
# label_provenance                        prediction_error_unverified

# %% [markdown]
# ## Reading
#
# GRU must beat persistence before recurrent state deserves further use.
#
# No lap precision, recall, count error, or duration error can be reported without independently reviewed boundaries.
