# %% [markdown]
# # 09 — Aggregate comparison report
#
# **Dataset:** `aim_2023`
#
# Reads saved artifacts only. Different tasks stay separate. No winner forced.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "lap_estimation").exists():
    ROOT = ROOT.parent
if not (ROOT / "lap_estimation").exists():
    raise FileNotFoundError("Repository root not found")
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from lap_estimation.comparison import METHOD_LABELS, RECORDING_METHODS, WINDOW_METHODS, build_recording_score_matrix, build_window_score_matrix, rank_method_scores
from lap_estimation.integration import build_recurrence_fusion, build_window_consensus
from lap_estimation.plotting_fusion import render_fusion_diagnostics
from lap_estimation.artifacts import load_experiment_metrics
from lap_estimation.config import RANDOM_SEED
from lap_estimation.data import prepare_recording_manifest
from lap_estimation.datasets import resolve_dataset
from lap_estimation.runners import run_experiment

DATASET_KEY = "aim_2023"
dataset = resolve_dataset(DATASET_KEY, ROOT)
ARTIFACT_ROOT = dataset.artifact_root
np.random.seed(RANDOM_SEED)
sns.set_theme(style="ticks", palette="colorblind", context="notebook")
manifest = prepare_recording_manifest(dataset)
manifest[["recording_id", "duration_s", "motion_status", "control_candidate", "clock_provenance", "split"]]
# Out:
#                                          recording_id  duration_s  \
# 0   18385fe48224fbfa0cd6d17705d9305f857d70ef07b47b...      228.95
# 1   27937681c8199780c6cbce603f217d5a4457c351e84fa3...      217.95
# 2   4975a35d789765b9299480af66d6a5af5166fef074cef8...      210.95
# 3   5790cd1534b1de5ac4693367fe5d8ca6951cd36a7abcd3...       25.95
# 4   5c12d7b5eff374be805bae6c5e2906f6c02b6bc3ad6ba7...       89.95
# 5   5c8af6b8a89a449144e0ddf74414040b433d630e1fd3d3...       33.95
# 6   6732a35a8f6343dcf041f1a3ad40d6760331513a2556c4...       21.95
# 7   7208a43e77536a72e401c00f01a793130fb6688d28fb80...        9.95
# 8   73093667f33a7f710fc20059989a002071359119e1e9c0...       10.95
# 9   8f799d59c9b5348ece1e5671692ea783d6d5e450ccebe3...      107.95
# 10  9116cbf4be063f5be851f65778ddfb91d60bdd5aa52e72...      456.95
# 11  973ef84ffaa4e83d002ed655331eb305b340c0f3f25b57...       12.95
# 12  b185f43818b8ff3aba325752922bbbf37fd094f1e28288...      123.95
# 13  b439fc5983a3a0db22239d5dcf8cbebf9104a8b71a93c2...       10.95
# 14  bace0e92b25324e8afbd0e5f6698b01a921780a2385e02...      241.95
# 15  c3c503093a73b359d513d025d9185c7ada423099650828...       20.95
# 16  db4d46d3c8abd3b8d2327e52a99599c63e7bd8ed5f1b12...       19.95
# 17  dc8bf44eb4cc0becf1c5ebe252a515c98193744c203149...      175.95
#
#              motion_status  control_candidate                clock_provenance  \
# 0        dynamic_candidate              False  inferred_uniform_from_metadata
# 1        dynamic_candidate              False  inferred_uniform_from_metadata
# 2        dynamic_candidate              False  inferred_uniform_from_metadata
# 3   low_dynamics_candidate               True  inferred_uniform_from_metadata
# 4        dynamic_candidate              False  inferred_uniform_from_metadata
# 5   low_dynamics_candidate               True  inferred_uniform_from_metadata
# 6        dynamic_candidate              False  inferred_uniform_from_metadata
# 7   low_dynamics_candidate               True  inferred_uniform_from_metadata
# 8   low_dynamics_candidate               True  inferred_uniform_from_metadata
# 9        dynamic_candidate              False  inferred_uniform_from_metadata
# 10       dynamic_candidate              False  inferred_uniform_from_metadata
# 11       dynamic_candidate              False  inferred_uniform_from_metadata
# 12       dynamic_candidate              False  inferred_uniform_from_metadata
# 13  low_dynamics_candidate               True  inferred_uniform_from_metadata
# 14       dynamic_candidate              False  inferred_uniform_from_metadata
# 15       dynamic_candidate              False  inferred_uniform_from_metadata
# 16  low_dynamics_candidate               True  inferred_uniform_from_metadata
# 17  low_dynamics_candidate               True  inferred_uniform_from_metadata
#
#          split
# 0        train
# 1        train
# 2        train
# 3        train
# 4        train
# 5        train
# 6        train
# 7        train
# 8        train
# 9        train
# 10       train
# 11  validation
# 12  validation
# 13  validation
# 14        test
# 15        test
# 16        test
# 17        test

# %%
METHODS = ["01_signal_processing", "02_dtw", "03_correlation", "04_learned_embeddings", "05_autoencoders", "06_contrastive_learning", "07_sequence_models", "08_unsupervised_learning"]
status_rows = []
for method in METHODS:
    path = ARTIFACT_ROOT / method / "manifest.json"
    if path.exists():
        run = json.loads(path.read_text(encoding="utf-8"))
        status_rows.append(
            {
                "method": method,
                "status": run.get("status"),
                "task": run.get("task"),
                "runtime_s": run.get("runtime_s"),
                "clock_provenance": run.get("data_provenance", {}).get("clock_provenance"),
                "sample_rate_hz": run.get("data_provenance", {}).get("native_sample_rate_hz"),
                "label_provenance": run.get("label_provenance"),
            }
        )
    else:
        status_rows.append({"method": method, "status": "not_run"})
run_status = pd.DataFrame(status_rows)
run_status
# Out:
#                      method    status  \
# 0      01_signal_processing  complete
# 1                    02_dtw  complete
# 2            03_correlation  complete
# 3     04_learned_embeddings  complete
# 4           05_autoencoders  complete
# 5   06_contrastive_learning  complete
# 6        07_sequence_models  complete
# 7  08_unsupervised_learning  complete
#
#                                          task  runtime_s  \
# 0      unverified_recurrence_period_detection      3.415
# 1           time_warped_period_pair_retrieval      6.412
# 2           channel_recurrence_and_sensor_lag      7.343
# 3       masked_signal_representation_learning      5.602
# 4  window_reconstruction_and_latent_neighbors      5.572
# 5       self_supervised_contrastive_retrieval      9.557
# 6                      next_sample_prediction     26.096
# 7                   driving_regime_clustering      3.719
#
#                  clock_provenance  sample_rate_hz  \
# 0  inferred_uniform_from_metadata            20.0
# 1  inferred_uniform_from_metadata            20.0
# 2  inferred_uniform_from_metadata            20.0
# 3  inferred_uniform_from_metadata            20.0
# 4  inferred_uniform_from_metadata            20.0
# 5  inferred_uniform_from_metadata            20.0
# 6  inferred_uniform_from_metadata            20.0
# 7  inferred_uniform_from_metadata            20.0
#
#                        label_provenance
# 0  signal_processing_teacher_unverified
# 1      signal_period_teacher_unverified
# 2         unverified_channel_recurrence
# 3            self_supervised_unverified
# 4       reconstruction_score_unverified
# 5  same_window_augmentations_unverified
# 6           prediction_error_unverified
# 7                cluster_regime_not_lap

# %%
metrics = load_experiment_metrics(ARTIFACT_ROOT)
display(metrics.sort_values(["task", "metric", "method"]))
comparison_keys = ["task", "split", "metric", "reference_source"]
comparison_table = metrics.pivot_table(index=comparison_keys, columns="method", values="value", aggfunc="first")
display(comparison_table)
metrics.to_csv(ARTIFACT_ROOT / "comparison_metrics.csv", index=False)
# Out:
#                       method                       task       split  \
# 36   06_contrastive_learning     augmentation_retrieval       train
# 37   06_contrastive_learning     augmentation_retrieval  validation
# 38   06_contrastive_learning     augmentation_retrieval        test
# 39   06_contrastive_learning     augmentation_retrieval         all
# 12            03_correlation      channel_lag_consensus       train
# 13            03_correlation      channel_lag_consensus  validation
# 14            03_correlation      channel_lag_consensus        test
# 15            03_correlation      channel_lag_consensus         all
# 3       01_signal_processing               data_quality         all
# 55  08_unsupervised_learning  driving_regime_clustering       train
# 56  08_unsupervised_learning  driving_regime_clustering  validation
# 57  08_unsupervised_learning  driving_regime_clustering        test
# 58  08_unsupervised_learning  driving_regime_clustering         all
# 54  08_unsupervised_learning  driving_regime_clustering       train
# 52  08_unsupervised_learning  driving_regime_clustering       train
# 53  08_unsupervised_learning  driving_regime_clustering       train
# 24     04_learned_embeddings        embedding_retrieval       train
# 25     04_learned_embeddings        embedding_retrieval  validation
# 26     04_learned_embeddings        embedding_retrieval        test
# 27     04_learned_embeddings        embedding_retrieval         all
# 40   06_contrastive_learning        embedding_retrieval       train
# 41   06_contrastive_learning        embedding_retrieval  validation
# 42   06_contrastive_learning        embedding_retrieval        test
# 43   06_contrastive_learning        embedding_retrieval         all
# 20     04_learned_embeddings   masked_signal_prediction       train
# 21     04_learned_embeddings   masked_signal_prediction  validation
# 22     04_learned_embeddings   masked_signal_prediction        test
# 23     04_learned_embeddings   masked_signal_prediction         all
# 44        07_sequence_models     next_sample_prediction       train
# 45        07_sequence_models     next_sample_prediction  validation
# 46        07_sequence_models     next_sample_prediction        test
# 47        07_sequence_models     next_sample_prediction         all
# 48        07_sequence_models     next_sample_prediction       train
# 49        07_sequence_models     next_sample_prediction  validation
# 50        07_sequence_models     next_sample_prediction        test
# 51        07_sequence_models     next_sample_prediction         all
# 5                     02_dtw      period_pair_retrieval       train
# 7                     02_dtw      period_pair_retrieval  validation
# 9                     02_dtw      period_pair_retrieval        test
# 11                    02_dtw      period_pair_retrieval         all
# 4                     02_dtw      period_pair_retrieval       train
# 6                     02_dtw      period_pair_retrieval  validation
# 8                     02_dtw      period_pair_retrieval        test
# 10                    02_dtw      period_pair_retrieval         all
# 2       01_signal_processing                 recurrence         all
# 0       01_signal_processing                 recurrence         all
# 1       01_signal_processing                 recurrence         all
# 16            03_correlation   sensor_cross_correlation       train
# 17            03_correlation   sensor_cross_correlation  validation
# 18            03_correlation   sensor_cross_correlation        test
# 19            03_correlation   sensor_cross_correlation         all
# 28           05_autoencoders      window_reconstruction       train
# 29           05_autoencoders      window_reconstruction  validation
# 30           05_autoencoders      window_reconstruction        test
# 31           05_autoencoders      window_reconstruction         all
# 32           05_autoencoders      window_reconstruction       train
# 33           05_autoencoders      window_reconstruction  validation
# 34           05_autoencoders      window_reconstruction        test
# 35           05_autoencoders      window_reconstruction         all
#
#                                metric      value  sample_count  \
# 36        mean_view_cosine_similarity   0.986389           662
# 37        mean_view_cosine_similarity   0.981839            61
# 38        mean_view_cosine_similarity   0.989772           213
# 39        mean_view_cosine_similarity   0.986863           936
# 12                     mean_lag_mad_s   2.371429             7
# 13                     mean_lag_mad_s   0.250000             1
# 14                     mean_lag_mad_s   5.000000             2
# 15                     mean_lag_mad_s   2.685000            10
# 3               duplicate_alias_count   0.000000            18
# 55             mean_centroid_distance   1.938081           662
# 56             mean_centroid_distance   2.844564            61
# 57             mean_centroid_distance   1.363307           213
# 58             mean_centroid_distance   1.866359           936
# 54           seed_adjusted_rand_index   1.000000           662
# 52             selected_cluster_count   3.000000           662
# 53                         silhouette   0.666522           662
# 24    mean_neighbor_cosine_similarity   0.998344           662
# 25    mean_neighbor_cosine_similarity   0.989338            61
# 26    mean_neighbor_cosine_similarity   0.999793           213
# 27    mean_neighbor_cosine_similarity   0.998087           936
# 40    mean_neighbor_cosine_similarity   0.967497           662
# 41    mean_neighbor_cosine_similarity   0.969139            61
# 42    mean_neighbor_cosine_similarity   0.981220           213
# 43    mean_neighbor_cosine_similarity   0.970727           936
# 20            mean_reconstruction_mse  47.257380           662
# 21            mean_reconstruction_mse  96.149936            61
# 22            mean_reconstruction_mse  21.756220           213
# 23            mean_reconstruction_mse  44.640605           936
# 44                            gru_mse  33.914346           662
# 45                            gru_mse  71.156231            61
# 46                            gru_mse  15.166861           213
# 47                            gru_mse  32.075180           936
# 48                    persistence_mse   4.306843           662
# 49                    persistence_mse  10.307184            61
# 50                    persistence_mse   1.941405           213
# 51                    persistence_mse   4.159602           936
# 5    matched_better_than_control_rate   0.822581            62
# 7    matched_better_than_control_rate   0.300000            10
# 9    matched_better_than_control_rate   0.700000            20
# 11   matched_better_than_control_rate   0.739130            92
# 4                  median_matched_dtw   0.939389            62
# 6                  median_matched_dtw  25.378825            10
# 8                  median_matched_dtw   0.369471            20
# 10                 median_matched_dtw   0.644651            92
# 2    control_candidate_detection_rate   0.500000             2
# 0      non_control_recording_coverage   0.727273            11
# 1   non_control_review_candidate_rate   0.125000             8
# 16   median_absolute_peak_correlation   0.655753           110
# 17   median_absolute_peak_correlation   0.741878            30
# 18   median_absolute_peak_correlation   0.442053            40
# 19   median_absolute_peak_correlation   0.655753           180
# 28                    autoencoder_mse  16.333256           662
# 29                    autoencoder_mse  49.383200            61
# 30                    autoencoder_mse   9.359964           213
# 31                    autoencoder_mse  16.900281           936
# 32                            pca_mse  16.667065           662
# 33                            pca_mse  45.459167            61
# 34                            pca_mse   9.046168           213
# 35                            pca_mse  16.809231           936
#
#                   reference_source
# 36       same_window_augmentations
# 37       same_window_augmentations
# 38       same_window_augmentations
# 39       same_window_augmentations
# 12                            none
# 13                            none
# 14                            none
# 15                            none
# 3                           sha256
# 55                            none
# 56                            none
# 57                            none
# 58                            none
# 54                   internal_only
# 52              internal_selection
# 53                   internal_only
# 24                            none
# 25                            none
# 26                            none
# 27                            none
# 40                            none
# 41                            none
# 42                            none
# 43                            none
# 20                            none
# 21                            none
# 22                            none
# 23                            none
# 44                            none
# 45                            none
# 46                            none
# 47                            none
# 48            persistence_baseline
# 49            persistence_baseline
# 50            persistence_baseline
# 51            persistence_baseline
# 5         within_recording_control
# 7         within_recording_control
# 9         within_recording_control
# 11        within_recording_control
# 4            signal_period_teacher
# 6            signal_period_teacher
# 8            signal_period_teacher
# 10           signal_period_teacher
# 2   training_low_dynamics_quantile
# 0                             none
# 1             unverified_threshold
# 16                            none
# 17                            none
# 18                            none
# 19                            none
# 28                            none
# 29                            none
# 30                            none
# 31                            none
# 32                            none
# 33                            none
# 34                            none
# 35                            none
# method                                                                                                 01_signal_processing  \
# task                      split      metric                            reference_source
# augmentation_retrieval    all        mean_view_cosine_similarity       same_window_augmentations                        NaN
#                           test       mean_view_cosine_similarity       same_window_augmentations                        NaN
#                           train      mean_view_cosine_similarity       same_window_augmentations                        NaN
#                           validation mean_view_cosine_similarity       same_window_augmentations                        NaN
# channel_lag_consensus     all        mean_lag_mad_s                    none                                             NaN
#                           test       mean_lag_mad_s                    none                                             NaN
#                           train      mean_lag_mad_s                    none                                             NaN
#                           validation mean_lag_mad_s                    none                                             NaN
# data_quality              all        duplicate_alias_count             sha256                                      0.000000
# driving_regime_clustering all        mean_centroid_distance            none                                             NaN
#                           test       mean_centroid_distance            none                                             NaN
#                           train      mean_centroid_distance            none                                             NaN
#                                      seed_adjusted_rand_index          internal_only                                    NaN
#                                      selected_cluster_count            internal_selection                               NaN
#                                      silhouette                        internal_only                                    NaN
#                           validation mean_centroid_distance            none                                             NaN
# embedding_retrieval       all        mean_neighbor_cosine_similarity   none                                             NaN
#                           test       mean_neighbor_cosine_similarity   none                                             NaN
#                           train      mean_neighbor_cosine_similarity   none                                             NaN
#                           validation mean_neighbor_cosine_similarity   none                                             NaN
# masked_signal_prediction  all        mean_reconstruction_mse           none                                             NaN
#                           test       mean_reconstruction_mse           none                                             NaN
#                           train      mean_reconstruction_mse           none                                             NaN
#                           validation mean_reconstruction_mse           none                                             NaN
# next_sample_prediction    all        gru_mse                           none                                             NaN
#                                      persistence_mse                   persistence_baseline                             NaN
#                           test       gru_mse                           none                                             NaN
#                                      persistence_mse                   persistence_baseline                             NaN
#                           train      gru_mse                           none                                             NaN
#                                      persistence_mse                   persistence_baseline                             NaN
#                           validation gru_mse                           none                                             NaN
#                                      persistence_mse                   persistence_baseline                             NaN
# period_pair_retrieval     all        matched_better_than_control_rate  within_recording_control                         NaN
#                                      median_matched_dtw                signal_period_teacher                            NaN
#                           test       matched_better_than_control_rate  within_recording_control                         NaN
#                                      median_matched_dtw                signal_period_teacher                            NaN
#                           train      matched_better_than_control_rate  within_recording_control                         NaN
#                                      median_matched_dtw                signal_period_teacher                            NaN
#                           validation matched_better_than_control_rate  within_recording_control                         NaN
#                                      median_matched_dtw                signal_period_teacher                            NaN
# recurrence                all        control_candidate_detection_rate  training_low_dynamics_quantile              0.500000
#                                      non_control_recording_coverage    none                                        0.727273
#                                      non_control_review_candidate_rate unverified_threshold                        0.125000
# sensor_cross_correlation  all        median_absolute_peak_correlation  none                                             NaN
#                           test       median_absolute_peak_correlation  none                                             NaN
#                           train      median_absolute_peak_correlation  none                                             NaN
#                           validation median_absolute_peak_correlation  none                                             NaN
# window_reconstruction     all        autoencoder_mse                   none                                             NaN
#                                      pca_mse                           none                                             NaN
#                           test       autoencoder_mse                   none                                             NaN
#                                      pca_mse                           none                                             NaN
#                           train      autoencoder_mse                   none                                             NaN
#                                      pca_mse                           none                                             NaN
#                           validation autoencoder_mse                   none                                             NaN
#                                      pca_mse                           none                                             NaN
#
# method                                                                                                    02_dtw  \
# task                      split      metric                            reference_source
# augmentation_retrieval    all        mean_view_cosine_similarity       same_window_augmentations             NaN
#                           test       mean_view_cosine_similarity       same_window_augmentations             NaN
#                           train      mean_view_cosine_similarity       same_window_augmentations             NaN
#                           validation mean_view_cosine_similarity       same_window_augmentations             NaN
# channel_lag_consensus     all        mean_lag_mad_s                    none                                  NaN
#                           test       mean_lag_mad_s                    none                                  NaN
#                           train      mean_lag_mad_s                    none                                  NaN
#                           validation mean_lag_mad_s                    none                                  NaN
# data_quality              all        duplicate_alias_count             sha256                                NaN
# driving_regime_clustering all        mean_centroid_distance            none                                  NaN
#                           test       mean_centroid_distance            none                                  NaN
#                           train      mean_centroid_distance            none                                  NaN
#                                      seed_adjusted_rand_index          internal_only                         NaN
#                                      selected_cluster_count            internal_selection                    NaN
#                                      silhouette                        internal_only                         NaN
#                           validation mean_centroid_distance            none                                  NaN
# embedding_retrieval       all        mean_neighbor_cosine_similarity   none                                  NaN
#                           test       mean_neighbor_cosine_similarity   none                                  NaN
#                           train      mean_neighbor_cosine_similarity   none                                  NaN
#                           validation mean_neighbor_cosine_similarity   none                                  NaN
# masked_signal_prediction  all        mean_reconstruction_mse           none                                  NaN
#                           test       mean_reconstruction_mse           none                                  NaN
#                           train      mean_reconstruction_mse           none                                  NaN
#                           validation mean_reconstruction_mse           none                                  NaN
# next_sample_prediction    all        gru_mse                           none                                  NaN
#                                      persistence_mse                   persistence_baseline                  NaN
#                           test       gru_mse                           none                                  NaN
#                                      persistence_mse                   persistence_baseline                  NaN
#                           train      gru_mse                           none                                  NaN
#                                      persistence_mse                   persistence_baseline                  NaN
#                           validation gru_mse                           none                                  NaN
#                                      persistence_mse                   persistence_baseline                  NaN
# period_pair_retrieval     all        matched_better_than_control_rate  within_recording_control         0.739130
#                                      median_matched_dtw                signal_period_teacher            0.644651
#                           test       matched_better_than_control_rate  within_recording_control         0.700000
#                                      median_matched_dtw                signal_period_teacher            0.369471
#                           train      matched_better_than_control_rate  within_recording_control         0.822581
#                                      median_matched_dtw                signal_period_teacher            0.939389
#                           validation matched_better_than_control_rate  within_recording_control         0.300000
#                                      median_matched_dtw                signal_period_teacher           25.378825
# recurrence                all        control_candidate_detection_rate  training_low_dynamics_quantile        NaN
#                                      non_control_recording_coverage    none                                  NaN
#                                      non_control_review_candidate_rate unverified_threshold                  NaN
# sensor_cross_correlation  all        median_absolute_peak_correlation  none                                  NaN
#                           test       median_absolute_peak_correlation  none                                  NaN
#                           train      median_absolute_peak_correlation  none                                  NaN
#                           validation median_absolute_peak_correlation  none                                  NaN
# window_reconstruction     all        autoencoder_mse                   none                                  NaN
#                                      pca_mse                           none                                  NaN
#                           test       autoencoder_mse                   none                                  NaN
#                                      pca_mse                           none                                  NaN
#                           train      autoencoder_mse                   none                                  NaN
#                                      pca_mse                           none                                  NaN
#                           validation autoencoder_mse                   none                                  NaN
#                                      pca_mse                           none                                  NaN
#
# method                                                                                                 03_correlation  \
# task                      split      metric                            reference_source
# augmentation_retrieval    all        mean_view_cosine_similarity       same_window_augmentations                  NaN
#                           test       mean_view_cosine_similarity       same_window_augmentations                  NaN
#                           train      mean_view_cosine_similarity       same_window_augmentations                  NaN
#                           validation mean_view_cosine_similarity       same_window_augmentations                  NaN
# channel_lag_consensus     all        mean_lag_mad_s                    none                                  2.685000
#                           test       mean_lag_mad_s                    none                                  5.000000
#                           train      mean_lag_mad_s                    none                                  2.371429
#                           validation mean_lag_mad_s                    none                                  0.250000
# data_quality              all        duplicate_alias_count             sha256                                     NaN
# driving_regime_clustering all        mean_centroid_distance            none                                       NaN
#                           test       mean_centroid_distance            none                                       NaN
#                           train      mean_centroid_distance            none                                       NaN
#                                      seed_adjusted_rand_index          internal_only                              NaN
#                                      selected_cluster_count            internal_selection                         NaN
#                                      silhouette                        internal_only                              NaN
#                           validation mean_centroid_distance            none                                       NaN
# embedding_retrieval       all        mean_neighbor_cosine_similarity   none                                       NaN
#                           test       mean_neighbor_cosine_similarity   none                                       NaN
#                           train      mean_neighbor_cosine_similarity   none                                       NaN
#                           validation mean_neighbor_cosine_similarity   none                                       NaN
# masked_signal_prediction  all        mean_reconstruction_mse           none                                       NaN
#                           test       mean_reconstruction_mse           none                                       NaN
#                           train      mean_reconstruction_mse           none                                       NaN
#                           validation mean_reconstruction_mse           none                                       NaN
# next_sample_prediction    all        gru_mse                           none                                       NaN
#                                      persistence_mse                   persistence_baseline                       NaN
#                           test       gru_mse                           none                                       NaN
#                                      persistence_mse                   persistence_baseline                       NaN
#                           train      gru_mse                           none                                       NaN
#                                      persistence_mse                   persistence_baseline                       NaN
#                           validation gru_mse                           none                                       NaN
#                                      persistence_mse                   persistence_baseline                       NaN
# period_pair_retrieval     all        matched_better_than_control_rate  within_recording_control                   NaN
#                                      median_matched_dtw                signal_period_teacher                      NaN
#                           test       matched_better_than_control_rate  within_recording_control                   NaN
#                                      median_matched_dtw                signal_period_teacher                      NaN
#                           train      matched_better_than_control_rate  within_recording_control                   NaN
#                                      median_matched_dtw                signal_period_teacher                      NaN
#                           validation matched_better_than_control_rate  within_recording_control                   NaN
#                                      median_matched_dtw                signal_period_teacher                      NaN
# recurrence                all        control_candidate_detection_rate  training_low_dynamics_quantile             NaN
#                                      non_control_recording_coverage    none                                       NaN
#                                      non_control_review_candidate_rate unverified_threshold                       NaN
# sensor_cross_correlation  all        median_absolute_peak_correlation  none                                  0.655753
#                           test       median_absolute_peak_correlation  none                                  0.442053
#                           train      median_absolute_peak_correlation  none                                  0.655753
#                           validation median_absolute_peak_correlation  none                                  0.741878
# window_reconstruction     all        autoencoder_mse                   none                                       NaN
#                                      pca_mse                           none                                       NaN
#                           test       autoencoder_mse                   none                                       NaN
#                                      pca_mse                           none                                       NaN
#                           train      autoencoder_mse                   none                                       NaN
#                                      pca_mse                           none                                       NaN
#                           validation autoencoder_mse                   none                                       NaN
#                                      pca_mse                           none                                       NaN
#
# method                                                                                                 04_learned_embeddings  \
# task                      split      metric                            reference_source
# augmentation_retrieval    all        mean_view_cosine_similarity       same_window_augmentations                         NaN
#                           test       mean_view_cosine_similarity       same_window_augmentations                         NaN
#                           train      mean_view_cosine_similarity       same_window_augmentations                         NaN
#                           validation mean_view_cosine_similarity       same_window_augmentations                         NaN
# channel_lag_consensus     all        mean_lag_mad_s                    none                                              NaN
#                           test       mean_lag_mad_s                    none                                              NaN
#                           train      mean_lag_mad_s                    none                                              NaN
#                           validation mean_lag_mad_s                    none                                              NaN
# data_quality              all        duplicate_alias_count             sha256                                            NaN
# driving_regime_clustering all        mean_centroid_distance            none                                              NaN
#                           test       mean_centroid_distance            none                                              NaN
#                           train      mean_centroid_distance            none                                              NaN
#                                      seed_adjusted_rand_index          internal_only                                     NaN
#                                      selected_cluster_count            internal_selection                                NaN
#                                      silhouette                        internal_only                                     NaN
#                           validation mean_centroid_distance            none                                              NaN
# embedding_retrieval       all        mean_neighbor_cosine_similarity   none                                         0.998087
#                           test       mean_neighbor_cosine_similarity   none                                         0.999793
#                           train      mean_neighbor_cosine_similarity   none                                         0.998344
#                           validation mean_neighbor_cosine_similarity   none                                         0.989338
# masked_signal_prediction  all        mean_reconstruction_mse           none                                        44.640605
#                           test       mean_reconstruction_mse           none                                        21.756220
#                           train      mean_reconstruction_mse           none                                        47.257380
#                           validation mean_reconstruction_mse           none                                        96.149936
# next_sample_prediction    all        gru_mse                           none                                              NaN
#                                      persistence_mse                   persistence_baseline                              NaN
#                           test       gru_mse                           none                                              NaN
#                                      persistence_mse                   persistence_baseline                              NaN
#                           train      gru_mse                           none                                              NaN
#                                      persistence_mse                   persistence_baseline                              NaN
#                           validation gru_mse                           none                                              NaN
#                                      persistence_mse                   persistence_baseline                              NaN
# period_pair_retrieval     all        matched_better_than_control_rate  within_recording_control                          NaN
#                                      median_matched_dtw                signal_period_teacher                             NaN
#                           test       matched_better_than_control_rate  within_recording_control                          NaN
#                                      median_matched_dtw                signal_period_teacher                             NaN
#                           train      matched_better_than_control_rate  within_recording_control                          NaN
#                                      median_matched_dtw                signal_period_teacher                             NaN
#                           validation matched_better_than_control_rate  within_recording_control                          NaN
#                                      median_matched_dtw                signal_period_teacher                             NaN
# recurrence                all        control_candidate_detection_rate  training_low_dynamics_quantile                    NaN
#                                      non_control_recording_coverage    none                                              NaN
#                                      non_control_review_candidate_rate unverified_threshold                              NaN
# sensor_cross_correlation  all        median_absolute_peak_correlation  none                                              NaN
#                           test       median_absolute_peak_correlation  none                                              NaN
#                           train      median_absolute_peak_correlation  none                                              NaN
#                           validation median_absolute_peak_correlation  none                                              NaN
# window_reconstruction     all        autoencoder_mse                   none                                              NaN
#                                      pca_mse                           none                                              NaN
#                           test       autoencoder_mse                   none                                              NaN
#                                      pca_mse                           none                                              NaN
#                           train      autoencoder_mse                   none                                              NaN
#                                      pca_mse                           none                                              NaN
#                           validation autoencoder_mse                   none                                              NaN
#                                      pca_mse                           none                                              NaN
#
# method                                                                                                 05_autoencoders  \
# task                      split      metric                            reference_source
# augmentation_retrieval    all        mean_view_cosine_similarity       same_window_augmentations                   NaN
#                           test       mean_view_cosine_similarity       same_window_augmentations                   NaN
#                           train      mean_view_cosine_similarity       same_window_augmentations                   NaN
#                           validation mean_view_cosine_similarity       same_window_augmentations                   NaN
# channel_lag_consensus     all        mean_lag_mad_s                    none                                        NaN
#                           test       mean_lag_mad_s                    none                                        NaN
#                           train      mean_lag_mad_s                    none                                        NaN
#                           validation mean_lag_mad_s                    none                                        NaN
# data_quality              all        duplicate_alias_count             sha256                                      NaN
# driving_regime_clustering all        mean_centroid_distance            none                                        NaN
#                           test       mean_centroid_distance            none                                        NaN
#                           train      mean_centroid_distance            none                                        NaN
#                                      seed_adjusted_rand_index          internal_only                               NaN
#                                      selected_cluster_count            internal_selection                          NaN
#                                      silhouette                        internal_only                               NaN
#                           validation mean_centroid_distance            none                                        NaN
# embedding_retrieval       all        mean_neighbor_cosine_similarity   none                                        NaN
#                           test       mean_neighbor_cosine_similarity   none                                        NaN
#                           train      mean_neighbor_cosine_similarity   none                                        NaN
#                           validation mean_neighbor_cosine_similarity   none                                        NaN
# masked_signal_prediction  all        mean_reconstruction_mse           none                                        NaN
#                           test       mean_reconstruction_mse           none                                        NaN
#                           train      mean_reconstruction_mse           none                                        NaN
#                           validation mean_reconstruction_mse           none                                        NaN
# next_sample_prediction    all        gru_mse                           none                                        NaN
#                                      persistence_mse                   persistence_baseline                        NaN
#                           test       gru_mse                           none                                        NaN
#                                      persistence_mse                   persistence_baseline                        NaN
#                           train      gru_mse                           none                                        NaN
#                                      persistence_mse                   persistence_baseline                        NaN
#                           validation gru_mse                           none                                        NaN
#                                      persistence_mse                   persistence_baseline                        NaN
# period_pair_retrieval     all        matched_better_than_control_rate  within_recording_control                    NaN
#                                      median_matched_dtw                signal_period_teacher                       NaN
#                           test       matched_better_than_control_rate  within_recording_control                    NaN
#                                      median_matched_dtw                signal_period_teacher                       NaN
#                           train      matched_better_than_control_rate  within_recording_control                    NaN
#                                      median_matched_dtw                signal_period_teacher                       NaN
#                           validation matched_better_than_control_rate  within_recording_control                    NaN
#                                      median_matched_dtw                signal_period_teacher                       NaN
# recurrence                all        control_candidate_detection_rate  training_low_dynamics_quantile              NaN
#                                      non_control_recording_coverage    none                                        NaN
#                                      non_control_review_candidate_rate unverified_threshold                        NaN
# sensor_cross_correlation  all        median_absolute_peak_correlation  none                                        NaN
#                           test       median_absolute_peak_correlation  none                                        NaN
#                           train      median_absolute_peak_correlation  none                                        NaN
#                           validation median_absolute_peak_correlation  none                                        NaN
# window_reconstruction     all        autoencoder_mse                   none                                  16.900281
#                                      pca_mse                           none                                  16.809231
#                           test       autoencoder_mse                   none                                   9.359964
#                                      pca_mse                           none                                   9.046168
#                           train      autoencoder_mse                   none                                  16.333256
#                                      pca_mse                           none                                  16.667065
#                           validation autoencoder_mse                   none                                  49.383200
#                                      pca_mse                           none                                  45.459167
#
# method                                                                                                 06_contrastive_learning  \
# task                      split      metric                            reference_source
# augmentation_retrieval    all        mean_view_cosine_similarity       same_window_augmentations                      0.986863
#                           test       mean_view_cosine_similarity       same_window_augmentations                      0.989772
#                           train      mean_view_cosine_similarity       same_window_augmentations                      0.986389
#                           validation mean_view_cosine_similarity       same_window_augmentations                      0.981839
# channel_lag_consensus     all        mean_lag_mad_s                    none                                                NaN
#                           test       mean_lag_mad_s                    none                                                NaN
#                           train      mean_lag_mad_s                    none                                                NaN
#                           validation mean_lag_mad_s                    none                                                NaN
# data_quality              all        duplicate_alias_count             sha256                                              NaN
# driving_regime_clustering all        mean_centroid_distance            none                                                NaN
#                           test       mean_centroid_distance            none                                                NaN
#                           train      mean_centroid_distance            none                                                NaN
#                                      seed_adjusted_rand_index          internal_only                                       NaN
#                                      selected_cluster_count            internal_selection                                  NaN
#                                      silhouette                        internal_only                                       NaN
#                           validation mean_centroid_distance            none                                                NaN
# embedding_retrieval       all        mean_neighbor_cosine_similarity   none                                           0.970727
# ...
#                           test       median_absolute_peak_correlation  none                                                NaN
#                           train      median_absolute_peak_correlation  none                                                NaN
#                           validation median_absolute_peak_correlation  none                                                NaN
# window_reconstruction     all        autoencoder_mse                   none                                                NaN
#                                      pca_mse                           none                                                NaN
#                           test       autoencoder_mse                   none                                                NaN
#                                      pca_mse                           none                                                NaN
#                           train      autoencoder_mse                   none                                                NaN
#                                      pca_mse                           none                                                NaN
#                           validation autoencoder_mse                   none                                                NaN
#                                      pca_mse                           none                                                NaN
#
# method                                                                                                 07_sequence_models  \
# task                      split      metric                            reference_source
# augmentation_retrieval    all        mean_view_cosine_similarity       same_window_augmentations                      NaN
#                           test       mean_view_cosine_similarity       same_window_augmentations                      NaN
#                           train      mean_view_cosine_similarity       same_window_augmentations                      NaN
#                           validation mean_view_cosine_similarity       same_window_augmentations                      NaN
# channel_lag_consensus     all        mean_lag_mad_s                    none                                           NaN
#                           test       mean_lag_mad_s                    none                                           NaN
#                           train      mean_lag_mad_s                    none                                           NaN
#                           validation mean_lag_mad_s                    none                                           NaN
# data_quality              all        duplicate_alias_count             sha256                                         NaN
# driving_regime_clustering all        mean_centroid_distance            none                                           NaN
#                           test       mean_centroid_distance            none                                           NaN
#                           train      mean_centroid_distance            none                                           NaN
#                                      seed_adjusted_rand_index          internal_only                                  NaN
#                                      selected_cluster_count            internal_selection                             NaN
#                                      silhouette                        internal_only                                  NaN
#                           validation mean_centroid_distance            none                                           NaN
# embedding_retrieval       all        mean_neighbor_cosine_similarity   none                                           NaN
#                           test       mean_neighbor_cosine_similarity   none                                           NaN
#                           train      mean_neighbor_cosine_similarity   none                                           NaN
#                           validation mean_neighbor_cosine_similarity   none                                           NaN
# masked_signal_prediction  all        mean_reconstruction_mse           none                                           NaN
#                           test       mean_reconstruction_mse           none                                           NaN
#                           train      mean_reconstruction_mse           none                                           NaN
#                           validation mean_reconstruction_mse           none                                           NaN
# next_sample_prediction    all        gru_mse                           none                                     32.075180
#                                      persistence_mse                   persistence_baseline                      4.159602
#                           test       gru_mse                           none                                     15.166861
#                                      persistence_mse                   persistence_baseline                      1.941405
#                           train      gru_mse                           none                                     33.914346
#                                      persistence_mse                   persistence_baseline                      4.306843
#                           validation gru_mse                           none                                     71.156231
#                                      persistence_mse                   persistence_baseline                     10.307184
# period_pair_retrieval     all        matched_better_than_control_rate  within_recording_control                       NaN
#                                      median_matched_dtw                signal_period_teacher                          NaN
#                           test       matched_better_than_control_rate  within_recording_control                       NaN
#                                      median_matched_dtw                signal_period_teacher                          NaN
#                           train      matched_better_than_control_rate  within_recording_control                       NaN
#                                      median_matched_dtw                signal_period_teacher                          NaN
#                           validation matched_better_than_control_rate  within_recording_control                       NaN
#                                      median_matched_dtw                signal_period_teacher                          NaN
# recurrence                all        control_candidate_detection_rate  training_low_dynamics_quantile                 NaN
#                                      non_control_recording_coverage    none                                           NaN
#                                      non_control_review_candidate_rate unverified_threshold                           NaN
# sensor_cross_correlation  all        median_absolute_peak_correlation  none                                           NaN
#                           test       median_absolute_peak_correlation  none                                           NaN
#                           train      median_absolute_peak_correlation  none                                           NaN
#                           validation median_absolute_peak_correlation  none                                           NaN
# window_reconstruction     all        autoencoder_mse                   none                                           NaN
#                                      pca_mse                           none                                           NaN
#                           test       autoencoder_mse                   none                                           NaN
#                                      pca_mse                           none                                           NaN
#                           train      autoencoder_mse                   none                                           NaN
#                                      pca_mse                           none                                           NaN
#                           validation autoencoder_mse                   none                                           NaN
#                                      pca_mse                           none                                           NaN
#
# method                                                                                                 08_unsupervised_learning
# task                      split      metric                            reference_source
# augmentation_retrieval    all        mean_view_cosine_similarity       same_window_augmentations                            NaN
#                           test       mean_view_cosine_similarity       same_window_augmentations                            NaN
#                           train      mean_view_cosine_similarity       same_window_augmentations                            NaN
#                           validation mean_view_cosine_similarity       same_window_augmentations                            NaN
# channel_lag_consensus     all        mean_lag_mad_s                    none                                                 NaN
#                           test       mean_lag_mad_s                    none                                                 NaN
#                           train      mean_lag_mad_s                    none                                                 NaN
#                           validation mean_lag_mad_s                    none                                                 NaN
# data_quality              all        duplicate_alias_count             sha256                                               NaN
# driving_regime_clustering all        mean_centroid_distance            none                                            1.866359
#                           test       mean_centroid_distance            none                                            1.363307
#                           train      mean_centroid_distance            none                                            1.938081
#                                      seed_adjusted_rand_index          internal_only                                   1.000000
#                                      selected_cluster_count            internal_selection                              3.000000
#                                      silhouette                        internal_only                                   0.666522
#                           validation mean_centroid_distance            none                                            2.844564
# embedding_retrieval       all        mean_neighbor_cosine_similarity   none                                                 NaN
#                           test       mean_neighbor_cosine_similarity   none                                                 NaN
#                           train      mean_neighbor_cosine_similarity   none                                                 NaN
#                           validation mean_neighbor_cosine_similarity   none                                                 NaN
# masked_signal_prediction  all        mean_reconstruction_mse           none                                                 NaN
#                           test       mean_reconstruction_mse           none                                                 NaN
#                           train      mean_reconstruction_mse           none                                                 NaN
#                           validation mean_reconstruction_mse           none                                                 NaN
# next_sample_prediction    all        gru_mse                           none                                                 NaN
#                                      persistence_mse                   persistence_baseline                                 NaN
#                           test       gru_mse                           none                                                 NaN
#                                      persistence_mse                   persistence_baseline                                 NaN
#                           train      gru_mse                           none                                                 NaN
#                                      persistence_mse                   persistence_baseline                                 NaN
#                           validation gru_mse                           none                                                 NaN
#                                      persistence_mse                   persistence_baseline                                 NaN
# period_pair_retrieval     all        matched_better_than_control_rate  within_recording_control                             NaN
#                                      median_matched_dtw                signal_period_teacher                                NaN
#                           test       matched_better_than_control_rate  within_recording_control                             NaN
#                                      median_matched_dtw                signal_period_teacher                                NaN
#                           train      matched_better_than_control_rate  within_recording_control                             NaN
#                                      median_matched_dtw                signal_period_teacher                                NaN
#                           validation matched_better_than_control_rate  within_recording_control                             NaN
#                                      median_matched_dtw                signal_period_teacher                                NaN
# recurrence                all        control_candidate_detection_rate  training_low_dynamics_quantile                       NaN
#                                      non_control_recording_coverage    none                                                 NaN
#                                      non_control_review_candidate_rate unverified_threshold                                 NaN
# sensor_cross_correlation  all        median_absolute_peak_correlation  none                                                 NaN
#                           test       median_absolute_peak_correlation  none                                                 NaN
#                           train      median_absolute_peak_correlation  none                                                 NaN
#                           validation median_absolute_peak_correlation  none                                                 NaN
# window_reconstruction     all        autoencoder_mse                   none                                                 NaN
#                                      pca_mse                           none                                                 NaN
#                           test       autoencoder_mse                   none                                                 NaN
#                                      pca_mse                           none                                                 NaN
#                           train      autoencoder_mse                   none                                                 NaN
#                                      pca_mse                           none                                                 NaN
#                           validation autoencoder_mse                   none                                                 NaN
#                                      pca_mse                           none                                                 NaN

# %%
def metric_value(method, metric, split="test"):
    selected = metrics.loc[(metrics["method"] == method) & (metrics["metric"] == metric) & (metrics["split"] == split), "value"]
    return float(selected.iloc[0]) if len(selected) else np.nan


findings = pd.DataFrame(
    [
        {"method": "Signal processing", "result": metric_value("01_signal_processing", "non_control_review_candidate_rate", "all"), "reading": "Review-candidate rate only; control detections remain visible."},
        {"method": "DTW", "result": metric_value("02_dtw", "matched_better_than_control_rate"), "reading": "Above 0.5 supports teacher-period pairs only."},
        {"method": "Correlation", "result": metric_value("03_correlation", "mean_lag_mad_s"), "reading": "Lower channel lag spread means consistency, not accuracy."},
        {"method": "Learned embeddings", "result": metric_value("04_learned_embeddings", "mean_neighbor_cosine_similarity"), "reading": "Near-unity values may mean overlap or collapse."},
        {"method": "Autoencoder", "result": metric_value("05_autoencoders", "autoencoder_mse") - metric_value("05_autoencoders", "pca_mse"), "reading": "Negative delta beats PCA."},
        {"method": "Contrastive learning", "result": metric_value("06_contrastive_learning", "mean_view_cosine_similarity"), "reading": "Measures augmentation invariance only."},
        {"method": "Sequence model", "result": metric_value("07_sequence_models", "gru_mse") - metric_value("07_sequence_models", "persistence_mse"), "reading": "Negative delta beats persistence."},
        {"method": "Unsupervised learning", "result": metric_value("08_unsupervised_learning", "seed_adjusted_rand_index", "train"), "reading": "Stable clusters remain operating regimes."},
    ]
)
findings.to_csv(ARTIFACT_ROOT / "report_findings.csv", index=False)
findings
# Out:
#                   method     result  \
# 0      Signal processing   0.125000
# 1                    DTW   0.700000
# 2            Correlation   5.000000
# 3     Learned embeddings   0.999793
# 4            Autoencoder   0.313795
# 5   Contrastive learning   0.989772
# 6         Sequence model  13.225456
# 7  Unsupervised learning   1.000000
#
#                                              reading
# 0  Review-candidate rate only; control detections...
# 1      Above 0.5 supports teacher-period pairs only.
# 2  Lower channel lag spread means consistency, no...
# 3    Near-unity values may mean overlap or collapse.
# 4                          Negative delta beats PCA.
# 5             Measures augmentation invariance only.
# 6                  Negative delta beats persistence.
# 7          Stable clusters remain operating regimes.

# %% [markdown]
# ## Method-score pairplots
#
# Recording view aggregates each method to median score per recording. Percentile ranks make unlike scales comparable. Reconstruction and sequence errors are reversed so higher rank means lower error. Complete-case count is small.
#
# Window view uses exact shared windows from embeddings, autoencoder, contrastive, sequence, and unsupervised methods. Overlapping windows are dependent observations. Correlations describe score behavior, not agreement on true laps.

# %%
sns.set_theme(style="ticks", palette="colorblind")
recording_scores = build_recording_score_matrix(ARTIFACT_ROOT)
recording_ranks = rank_method_scores(recording_scores, ["recording_id"])
recording_plot = recording_ranks.merge(manifest[["recording_id", "split", "motion_status"]], on="recording_id", how="left")
recording_columns = [METHOD_LABELS[method] for method in RECORDING_METHODS]
recording_complete = recording_plot.dropna(subset=recording_columns)
display(pd.Series({"all_recordings": len(recording_plot), "complete_recordings": len(recording_complete)}, name="count").to_frame())
grid = sns.pairplot(
    recording_complete,
    vars=recording_columns,
    hue="split",
    corner=True,
    diag_kind="hist",
    height=1.45,
    plot_kws={"s": 32, "alpha": 0.8},
)
grid.figure.suptitle(f"{DATASET_KEY}: recording-level method score ranks", y=1.01)
grid.savefig(ARTIFACT_ROOT / "recording_method_pairplot.png", dpi=180, bbox_inches="tight")
recording_plot.to_csv(ARTIFACT_ROOT / "recording_method_scores.csv", index=False)
# Out:
#                      count
# all_recordings          18
# complete_recordings     10

# %%
recording_correlation = recording_ranks[recording_columns].corr(method="spearman", min_periods=5)
recording_correlation.to_csv(ARTIFACT_ROOT / "recording_method_spearman.csv")
fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(recording_correlation, annot=True, fmt=".2f", cmap="vlag", center=0, vmin=-1, vmax=1, square=True, ax=ax)
ax.set_title(f"{DATASET_KEY}: recording-level Spearman correlation")
fig.tight_layout()
fig.savefig(ARTIFACT_ROOT / "recording_method_spearman.png", dpi=180, bbox_inches="tight")

# %%
window_scores = build_window_score_matrix(ARTIFACT_ROOT)
window_keys = ["recording_id", "start_s", "end_s"]
window_ranks = rank_method_scores(window_scores, window_keys)
window_plot = window_ranks.merge(manifest[["recording_id", "split"]], on="recording_id", how="left")
window_columns = [METHOD_LABELS[method] for method in WINDOW_METHODS]
grid = sns.pairplot(
    window_plot,
    vars=window_columns,
    hue="split",
    corner=True,
    diag_kind="hist",
    height=1.7,
    plot_kws={"s": 10, "alpha": 0.35},
)
grid.figure.suptitle(f"{DATASET_KEY}: exact-window method score ranks", y=1.01)
grid.savefig(ARTIFACT_ROOT / "window_method_pairplot.png", dpi=180, bbox_inches="tight")
window_plot.to_csv(ARTIFACT_ROOT / "window_method_scores.csv", index=False)
window_correlation = window_ranks[window_columns].corr(method="spearman")
window_correlation.to_csv(ARTIFACT_ROOT / "window_method_spearman.csv")
window_correlation
# Out:
#               Embeddings  Autoencoder  Contrastive  Sequence  Unsupervised
# Embeddings      1.000000     0.010939     0.460625  0.001457     -0.118054
# Autoencoder     0.010939     1.000000     0.163832  0.984014      0.813024
# Contrastive     0.460625     0.163832     1.000000  0.140782      0.028069
# Sequence        0.001457     0.984014     0.140782  1.000000      0.814169
# Unsupervised   -0.118054     0.813024     0.028069  0.814169      1.000000

# %% [markdown]
# ## Family-aware integration
#
# Recurrence fusion combines signal/correlation period evidence with DTW shape support. DTW depends on signal-derived teacher periods, so those two are not independent votes. Window consensus normalizes learned-method scores against training distributions only. Autoencoder and sequence errors contribute typicality context, not lap votes.

# %%
recurrence_fusion = build_recurrence_fusion(ARTIFACT_ROOT)
window_consensus = build_window_consensus(ARTIFACT_ROOT)
recurrence_fusion.to_csv(ARTIFACT_ROOT / "recurrence_fusion.csv", index=False)
window_consensus.to_csv(ARTIFACT_ROOT / "window_consensus.csv", index=False)
display(recurrence_fusion)
display(window_consensus.sort_values(["recording_id", "start_s"]))

fusion_figures = render_fusion_diagnostics(recurrence_fusion, window_consensus, {"dataset_key": DATASET_KEY}, ARTIFACT_ROOT)
for figure in fusion_figures.values():
    display(figure)
    plt.close(figure)
# Out:
#                                         recording_id  signal_score  \
# 0  18385fe48224fbfa0cd6d17705d9305f857d70ef07b47b...      0.250696
# 1  27937681c8199780c6cbce603f217d5a4457c351e84fa3...      0.204464
# 2  4975a35d789765b9299480af66d6a5af5166fef074cef8...      0.228681
# 3  8f799d59c9b5348ece1e5671692ea783d6d5e450ccebe3...      0.232961
# 4  dc8bf44eb4cc0becf1c5ebe252a515c98193744c203149...      0.253938
# 5  5c12d7b5eff374be805bae6c5e2906f6c02b6bc3ad6ba7...      0.176924
# 6  9116cbf4be063f5be851f65778ddfb91d60bdd5aa52e72...      0.118885
# 7  5c8af6b8a89a449144e0ddf74414040b433d630e1fd3d3...      0.002243
# 8  bace0e92b25324e8afbd0e5f6698b01a921780a2385e02...      0.189051
# 9  b185f43818b8ff3aba325752922bbbf37fd094f1e28288...      0.196036
#
#    signal_period_s  dtw_margin  dtw_pair_count  correlation_score  \
# 0            45.50    1.714187              10           0.237398
# 1            20.10   21.964125              10           0.246157
# 2            21.00   20.480237              10           0.236365
# 3            45.15    6.738922              10           0.340034
# 4            27.45    0.035632              10           0.176058
# 5            39.95    0.487705              10           0.225389
# 6            59.15    0.786747              10           0.109353
# 7            15.25    0.198161               2           0.117204
# 8            15.05   -0.017128              10           0.221776
# 9            46.00   -1.432502              10           0.240730
#
#    correlation_period_s  period_agreement  signal_support  dtw_support  \
# 0                 45.45          0.998901             0.9          0.7
# 1                 45.90          0.437908             0.6          1.0
# 2                 21.10          0.995261             0.7          0.9
# 3                 45.00          0.996678             0.8          0.8
# 4                 27.50          0.998182             1.0          0.3
# 5                 44.15          0.904870             0.3          0.5
# 6                 15.15          0.256128             0.2          0.6
# 7                 15.80          0.965190             0.1          0.4
# 8                 23.80          0.632353             0.4          0.2
# 9                 50.15          0.917248             0.5          0.1
#
#    correlation_support  period_support  signal_family_support  \
# 0                  0.7             1.0                    0.9
# 1                  0.9             0.2                    0.6
# 2                  0.6             0.7                    0.7
# 3                  1.0             0.8                    0.8
# 4                  0.3             0.9                    0.9
# 5                  0.5             0.4                    0.4
# 6                  0.1             0.1                    0.1
# 7                  0.2             0.6                    0.2
# 8                  0.4             0.3                    0.4
# 9                  0.8             0.5                    0.5
#
#    shape_family_support  fused_support  family_dispersion  method_count  \
# 0                   0.7           0.80               0.10             3
# 1                   1.0           0.80               0.20             3
# 2                   0.9           0.80               0.10             3
# 3                   0.8           0.80               0.00             3
# 4                   0.3           0.60               0.30             3
# 5                   0.5           0.45               0.05             3
# 6                   0.6           0.35               0.25             3
# 7                   0.4           0.30               0.10             3
# 8                   0.2           0.30               0.10             3
# 9                   0.1           0.30               0.20             3
#
#   evidence_status                 dependency_note
# 0          review  dtw_uses_signal_period_teacher
# 1            weak  dtw_uses_signal_period_teacher
# 2          review  dtw_uses_signal_period_teacher
# 3          review  dtw_uses_signal_period_teacher
# 4            weak  dtw_uses_signal_period_teacher
# 5            weak  dtw_uses_signal_period_teacher
# 6            weak  dtw_uses_signal_period_teacher
# 7            weak  dtw_uses_signal_period_teacher
# 8            weak  dtw_uses_signal_period_teacher
# 9            weak  dtw_uses_signal_period_teacher
#                                           recording_id  start_s  end_s  \
# 0    18385fe48224fbfa0cd6d17705d9305f857d70ef07b47b...      0.0   10.0
# 1    18385fe48224fbfa0cd6d17705d9305f857d70ef07b47b...      2.0   12.0
# 2    18385fe48224fbfa0cd6d17705d9305f857d70ef07b47b...      4.0   14.0
# 3    18385fe48224fbfa0cd6d17705d9305f857d70ef07b47b...      6.0   16.0
# 4    18385fe48224fbfa0cd6d17705d9305f857d70ef07b47b...      8.0   18.0
# ..                                                 ...      ...    ...
# 931  dc8bf44eb4cc0becf1c5ebe252a515c98193744c203149...    158.0  168.0
# 932  dc8bf44eb4cc0becf1c5ebe252a515c98193744c203149...    160.0  170.0
# 933  dc8bf44eb4cc0becf1c5ebe252a515c98193744c203149...    162.0  172.0
# 934  dc8bf44eb4cc0becf1c5ebe252a515c98193744c203149...    164.0  174.0
# 935  dc8bf44eb4cc0becf1c5ebe252a515c98193744c203149...    166.0  176.0
#
#      Embeddings  Autoencoder  Contrastive  Sequence  Unsupervised  split  \
# 0      0.999985     1.263434     0.995855  1.924615     -1.752613  train
# 1      0.999750     0.474689     0.990964  0.383169     -0.587018  train
# 2      0.999999     0.056868     0.985927  0.053276     -0.631642  train
# 3      0.999994     0.055263     0.994272  0.052744     -0.661098  train
# 4      0.999994     0.060315     0.994491  0.057648     -0.665145  train
# ..          ...          ...          ...       ...           ...    ...
# 931    0.999891     0.427027     0.951580  0.295741     -0.945333   test
# 932    0.999994     2.247686     0.994862  1.773196     -2.301107   test
# 933    0.999989     2.464107     0.989217  2.838751     -3.393374   test
# 934    0.999990     2.398451     0.993499  3.337969     -4.142009   test
# 935    0.999986     2.517099     0.996182  3.721194     -4.815262   test
#
#      Embeddings_support  Autoencoder_support  Contrastive_support  \
# 0              0.645015             0.451662             0.930514
# 1              0.249245             0.569486             0.814199
# 2              0.981873             0.868580             0.682779
# 3              0.848943             0.876133             0.906344
# 4              0.826284             0.845921             0.916918
# ..                  ...                  ...                  ...
# 931            0.339879             0.584592             0.216012
# 932            0.833837             0.416918             0.921450
# 933            0.716012             0.409366             0.771903
# 934            0.722054             0.412387             0.888218
# 935            0.654079             0.409366             0.938066
#
#      Sequence_support  Unsupervised_support  consensus_support  support_iqr  \
# 0            0.425982              0.432024           0.451662     0.212991
# 1            0.580060              0.879154           0.580060     0.244713
# 2            0.845921              0.841390           0.845921     0.027190
# 3            0.851964              0.788520           0.851964     0.027190
# 4            0.830816              0.774924           0.830816     0.019637
# ..                ...                   ...                ...          ...
# 931          0.598187              0.570997           0.570997     0.244713
# 932          0.429003              0.350453           0.429003     0.416918
# 933          0.416918              0.188822           0.416918     0.306647
# 934          0.410876              0.122356           0.412387     0.311178
# 935          0.404834              0.063444           0.409366     0.249245
#
#      method_count
# 0               5
# 1               5
# 2               5
# 3               5
# 4               5
# ..            ...
# 931             5
# 932             5
# 933             5
# 934             5
# 935             5
#
# [936 rows x 17 columns]

# %% [markdown]
# ## Report boundary
#
# No independent lap boundaries or GPS exist. Report compares engineering evidence, baselines, stability, and failure behavior. It cannot name an accurate lap detector.
